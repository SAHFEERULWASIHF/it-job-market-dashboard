# %%
import pandas as pd

# %%
df1 = pd.read_csv("../Data/Raw/global_tech_salary_2020-2024.txt")
df1
# Out:
#       work_year experience_level employment_type  \
# 0          2023               MI              FT
# 1          2023               MI              FT
# 2          2024               MI              FT
# 3          2024               SE              FT
# 4          2023               MI              FT
# ...         ...              ...             ...
# 4995       2023               SE              FT
# 4996       2022               SE              FT
# 4997       2024               SE              FT
# 4998       2022               EN              FT
# 4999       2023               SE              FT
#
#                                      job_title  salary salary_currency  \
# 0                                 Data Analyst  165000             USD
# 1                                 Data Analyst   70000             USD
# 2                    Machine Learning Engineer   85000             EUR
# 3                               Data Scientist   92700             USD
# 4                            Research Engineer  150000             USD
# ...                                        ...     ...             ...
# 4995  Machine Learning Infrastructure Engineer   70000             EUR
# 4996                             Data Engineer  145000             USD
# 4997                 Machine Learning Engineer  153000             USD
# 4998                              AI Scientist   30000             EUR
# 4999                 Machine Learning Engineer  176000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 0            165000                 AU             0               AU
# 1             70000                 US           100               US
# 2             94444                 IE           100               IE
# 3             92700                 US             0               US
# 4            150000                 US             0               US
# ...             ...                ...           ...              ...
# 4995          75577                 FR           100               FR
# 4996         145000                 US             0               US
# 4997         153000                 US             0               US
# 4998          31520                 PT           100               ES
# 4999         176000                 US             0               US
#
#      company_size
# 0               M
# 1               M
# 2               M
# 3               M
# 4               M
# ...           ...
# 4995            M
# 4996            M
# 4997            M
# 4998            M
# 4999            M
#
# [5000 rows x 11 columns]

# %%
df1.work_year.value_counts()
# Out:
# work_year
# 2023    2921
# 2024    1445
# 2022     530
# 2021      79
# 2020      25
# Name: count, dtype: int64

# %%
df2= pd.read_excel("../Data/Raw/global_tech_salary_2020-2022.xlsx", sheet_name='Sheet1')
df2
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR          79833                 DE             0
# 1    260000             USD         260000                 JP             0
# 2     85000             GBP         109024                 GB            50
# 3     20000             USD          20000                 HN             0
# 4    150000             USD         150000                 US            50
# ..      ...             ...            ...                ...           ...
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 3                 HN            S
# 4                 US            L
# ..               ...          ...
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L
#
# [607 rows x 11 columns]

# %%
df2.work_year.value_counts()
# Out:
# work_year
# 2022    318
# 2021    217
# 2020     72
# Name: count, dtype: int64

# %%
df3 = pd.read_csv("../Data/Raw/archive/salaries.csv")
df3
# Out:
#         work_year experience_level employment_type                 job_title  \
# 0            2025               MI              FT                   Analyst
# 1            2025               MI              FT                   Analyst
# 2            2025               SE              FT         Data Quality Lead
# 3            2025               SE              FT         Data Quality Lead
# 4            2025               MI              FT   Data Quality Specialist
# ...           ...              ...             ...                       ...
# 146343       2020               SE              FT            Data Scientist
# 146344       2021               MI              FT  Principal Data Scientist
# 146345       2020               EN              FT            Data Scientist
# 146346       2020               EN              CT     Business Data Analyst
# 146347       2021               SE              FT            Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0        142000             USD         142000                 US
# 1         87000             USD          87000                 US
# 2        218700             USD         218700                 US
# 3        163200             USD         163200                 US
# 4        121524             USD         121524                 US
# ...         ...             ...            ...                ...
# 146343   412000             USD         412000                 US
# 146344   151000             USD         151000                 US
# 146345   105000             USD         105000                 US
# 146346   100000             USD         100000                 US
# 146347  7000000             INR          94665                 IN
#
#         remote_ratio company_location company_size
# 0                  0               US            M
# 1                  0               US            M
# 2                  0               US            M
# 3                  0               US            M
# 4                  0               US            M
# ...              ...              ...          ...
# 146343           100               US            L
# 146344           100               US            L
# 146345           100               US            S
# 146346           100               US            L
# 146347            50               IN            L
#
# [146348 rows x 11 columns]

# %%
df = pd.concat([df1,df2,df3], ignore_index=True)
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               MI              FT               Data Analyst
# 1       2023               MI              FT               Data Analyst
# 2       2024               MI              FT  Machine Learning Engineer
# 3       2024               SE              FT             Data Scientist
# 4       2023               MI              FT          Research Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  165000             USD         165000                 AU             0
# 1   70000             USD          70000                 US           100
# 2   85000             EUR          94444                 IE           100
# 3   92700             USD          92700                 US             0
# 4  150000             USD         150000                 US             0
#
#   company_location company_size
# 0               AU            M
# 1               US            M
# 2               IE            M
# 3               US            M
# 4               US            M

# %%
len(df1)
# Out:
# 5000

# %%
len(df2)
# Out:
# 607

# %%
len(df3)
# Out:
# 146348

# %%
len(df)
# Out:
# 151955

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 70208

# %%
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               MI              FT               Data Analyst
# 1       2023               MI              FT               Data Analyst
# 2       2024               MI              FT  Machine Learning Engineer
# 3       2024               SE              FT             Data Scientist
# 4       2023               MI              FT          Research Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  165000             USD         165000                 AU             0
# 1   70000             USD          70000                 US           100
# 2   85000             EUR          94444                 IE           100
# 3   92700             USD          92700                 US             0
# 4  150000             USD         150000                 US             0
#
#   company_location company_size
# 0               AU            M
# 1               US            M
# 2               IE            M
# 3               US            M
# 4               US            M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70208 entries, 0 to 151954
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           70208 non-null  int64
#  1   experience_level    70208 non-null  object
#  2   employment_type     70208 non-null  object
#  3   job_title           70208 non-null  object
#  4   salary              70208 non-null  int64
#  5   salary_currency     70208 non-null  object
#  6   salary_in_usd       70208 non-null  int64
#  7   employee_residence  70208 non-null  object
#  8   remote_ratio        70208 non-null  int64
#  9   company_location    70208 non-null  object
#  10  company_size        70208 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 6.4+ MB

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
import matplotlib.pyplot as plt  # type: ignore
import seaborn as sns # type: ignore
import numpy as np  # type: ignore

# %%
sns.boxplot(df['salary_in_usd'])
# Out:
# <Axes: ylabel='salary_in_usd'>

# %%
sns.histplot(df['salary_in_usd'])
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='Count'>

# %%
df.to_csv("../Data/Processed/cleaned_csv.csv")
